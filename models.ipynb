# %%
import pandas as pd
import numpy as np
import sys
import os
import scipy

# %%
file1 = pd.read_csv('2015_sample.csv')
file2 = pd.read_csv('2015_failures.csv')

# %%
file1.tail()
# Out:
#             date    serial_number                    model  capacity_bytes  \
# 1424  2015-07-02   PL1331LAGSR92H     HGST HMS5C4040ALE640   4000787030016
# 1425  2015-03-06   MJ1311YNG6116A  Hitachi HDS5C3030ALA630   3000592982016
# 1426  2015-07-13         Z300GQ8H              ST4000DM000   4000787030016
# 1427  2015-12-10   PL1331LAGSMTBH     HGST HMS5C4040ALE640   4000787030016
# 1428  2015-08-24  WD-WCAV39124230            WDC WD800AAJB     80026361856
#
#       failure  smart_1_normalized  smart_1_raw  smart_2_normalized  \
# 1424        0               100.0          0.0               133.0
# 1425        0               100.0          0.0               135.0
# 1426        0               118.0  173090296.0                 NaN
# 1427        0               100.0          0.0               133.0
# 1428        0               200.0          0.0                 NaN
#
#       smart_2_raw  smart_3_normalized      ...        smart_250_normalized  \
# 1424        104.0               100.0      ...                         NaN
# 1425        108.0               138.0      ...                         NaN
# 1426          NaN                95.0      ...                         NaN
# 1427        104.0               127.0      ...                         NaN
# 1428          NaN               142.0      ...                         NaN
#
#       smart_250_raw  smart_251_normalized  smart_251_raw  \
# 1424            NaN                   NaN            NaN
# 1425            NaN                   NaN            NaN
# 1426            NaN                   NaN            NaN
# 1427            NaN                   NaN            NaN
# 1428            NaN                   NaN            NaN
#
#       smart_252_normalized  smart_252_raw  smart_254_normalized  \
# 1424                   NaN            NaN                   NaN
# 1425                   NaN            NaN                   NaN
# 1426                   NaN            NaN                   NaN
# 1427                   NaN            NaN                   NaN
# 1428                   NaN            NaN                   NaN
#
#       smart_254_raw  smart_255_normalized  smart_255_raw
# 1424            NaN                   NaN            NaN
# 1425            NaN                   NaN            NaN
# 1426            NaN                   NaN            NaN
# 1427            NaN                   NaN            NaN
# 1428            NaN                   NaN            NaN
#
# [5 rows x 95 columns]

# %%
file1 = file1.dropna(0, thresh = 20)
file2 = file2.dropna(0, thresh = 20)

# %%
file1 = file1.dropna(axis=1)
file2 = file2.dropna(axis=1)

# %%
file2.tail()
# Out:
#             date serial_number                model  capacity_bytes  failure  \
# 1424  2015-07-06      Z3014PAK          ST4000DM000   4000787030016        1
# 1425  2015-07-12  45CHK11QFMYB  TOSHIBA MD04ABA400V   4000787030016        1
# 1426  2015-07-12      S1F0GPFZ          ST3000DM001   3000592982016        1
# 1427  2015-07-12      Z302AYTQ          ST4000DM000   4000787030016        1
# 1428  2015-07-12      S1F0J5JH          ST3000DM001   3000592982016        1
#
#       smart_1_normalized  smart_1_raw  smart_3_normalized  smart_3_raw  \
# 1424               114.0   71699456.0                91.0          0.0
# 1425               100.0          0.0               100.0       5393.0
# 1426               120.0  236544080.0                92.0          0.0
# 1427               114.0   71729768.0                93.0          0.0
# 1428               105.0    9995856.0                92.0          0.0
#
#       smart_4_normalized      ...        smart_12_normalized  smart_12_raw  \
# 1424               100.0      ...                      100.0          19.0
# 1425               100.0      ...                      100.0           2.0
# 1426               100.0      ...                      100.0          37.0
# 1427               100.0      ...                      100.0           9.0
# 1428               100.0      ...                      100.0          36.0
#
#       smart_194_normalized  smart_194_raw  smart_197_normalized  \
# 1424                  23.0           23.0                 100.0
# 1425                 100.0           23.0                 100.0
# 1426                  26.0           26.0                 100.0
# 1427                  23.0           23.0                 100.0
# 1428                  25.0           25.0                 100.0
#
#       smart_197_raw  smart_198_normalized  smart_198_raw  \
# 1424            0.0                 100.0            0.0
# 1425            0.0                 100.0            0.0
# 1426            0.0                 100.0            0.0
# 1427            0.0                 100.0            0.0
# 1428            0.0                 100.0            0.0
#
#       smart_199_normalized  smart_199_raw
# 1424                 200.0            0.0
# 1425                 200.0            0.0
# 1426                 200.0            0.0
# 1427                 200.0            0.0
# 1428                 200.0            0.0
#
# [5 rows x 29 columns]

# %%
columns = [ 'smart_1_normalized', 'smart_3_normalized', 'smart_4_normalized', 'smart_5_normalized',
           'smart_7_normalized','smart_12_normalized', 'smart_194_normalized', 
           'smart_197_normalized', 'smart_198_normalized', 'smart_199_normalized'
           ]

# %%
file2.tail()
# Out:
#             date serial_number                model  capacity_bytes  failure  \
# 1424  2015-07-06      Z3014PAK          ST4000DM000   4000787030016        1
# 1425  2015-07-12  45CHK11QFMYB  TOSHIBA MD04ABA400V   4000787030016        1
# 1426  2015-07-12      S1F0GPFZ          ST3000DM001   3000592982016        1
# 1427  2015-07-12      Z302AYTQ          ST4000DM000   4000787030016        1
# 1428  2015-07-12      S1F0J5JH          ST3000DM001   3000592982016        1
#
#       smart_1_normalized  smart_1_raw  smart_3_normalized  smart_3_raw  \
# 1424               114.0   71699456.0                91.0          0.0
# 1425               100.0          0.0               100.0       5393.0
# 1426               120.0  236544080.0                92.0          0.0
# 1427               114.0   71729768.0                93.0          0.0
# 1428               105.0    9995856.0                92.0          0.0
#
#       smart_4_normalized      ...        smart_12_normalized  smart_12_raw  \
# 1424               100.0      ...                      100.0          19.0
# 1425               100.0      ...                      100.0           2.0
# 1426               100.0      ...                      100.0          37.0
# 1427               100.0      ...                      100.0           9.0
# 1428               100.0      ...                      100.0          36.0
#
#       smart_194_normalized  smart_194_raw  smart_197_normalized  \
# 1424                  23.0           23.0                 100.0
# 1425                 100.0           23.0                 100.0
# 1426                  26.0           26.0                 100.0
# 1427                  23.0           23.0                 100.0
# 1428                  25.0           25.0                 100.0
#
#       smart_197_raw  smart_198_normalized  smart_198_raw  \
# 1424            0.0                 100.0            0.0
# 1425            0.0                 100.0            0.0
# 1426            0.0                 100.0            0.0
# 1427            0.0                 100.0            0.0
# 1428            0.0                 100.0            0.0
#
#       smart_199_normalized  smart_199_raw
# 1424                 200.0            0.0
# 1425                 200.0            0.0
# 1426                 200.0            0.0
# 1427                 200.0            0.0
# 1428                 200.0            0.0
#
# [5 rows x 29 columns]

# %%
df = pd.concat([file1,file2])
df1 = df[columns]
y = df['failure']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
lr1 = LogisticRegression(solver='newton-cg')
lr2 = LogisticRegression(solver='lbfgs')
lr3 = LogisticRegression(solver='saga')
lr4 = LogisticRegression(solver='sag')
lr5 = LogisticRegression(solver='liblinear')
rfc = RandomForestClassifier()
boost1 = GradientBoostingClassifier(loss='deviance')
boost2 = GradientBoostingClassifier(loss='exponential')
svm_rbf = SVC(kernel='rbf')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1, y, test_size=0.8,random_state=1)
for model in [lr1,lr2,lr3,lr4,lr5,rfc,svm_rbf]:
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print("Trained: ",model)
    print("Precision:",precision_score(y_test,y_pred))
    print("Recall:",recall_score(y_test,y_pred))
    print("Accuracy:",accuracy_score(y_test,y_pred))
    print("F1-Score",f1_score(y_test,y_pred))
# Out:
# Trained:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='newton-cg', tol=0.0001,
#           verbose=0, warm_start=False)
# Precision: 0.677734375
# Recall: 0.601908065915
# Accuracy: 0.654704595186
# F1-Score 0.637574644006
# Trained:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='lbfgs', tol=0.0001,
#           verbose=0, warm_start=False)
# Precision: 0.67972575906
# Recall: 0.601908065915
# Accuracy: 0.65601750547
# F1-Score 0.638454461822
# Trained:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='saga', tol=0.0001,
#           verbose=0, warm_start=False)
# Precision: 0.622205663189
# Recall: 0.724197745013
# Accuracy: 0.638949671772
# F1-Score 0.669338677355
# Trained:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=0, warm_start=False)
# Precision: 0.640833333333
# Recall: 0.666955767563
# Accuracy: 0.643326039387
# F1-Score 0.653633659159
# Trained:  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# Precision: 0.677702044791
# Recall: 0.603642671292
# Accuracy: 0.655142231947
# F1-Score 0.638532110092
# Trained:  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Precision: 0.680975609756
# Recall: 0.60537727667
# Accuracy: 0.657768052516
# F1-Score 0.640955004591
# Trained:  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Precision: 0.6232
# Recall: 0.675628794449
# Accuracy: 0.630196936543
# F1-Score 0.64835622139

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
for model in [lr1,lr2,lr3,lr4,lr5, rfc,boost1]:
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=0)
    plt.plot(tpr,fpr)
    plt.show()

# %%
from sklearn import linear_model
model = linear_model.SGDClassifier(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Trained: ",model)
print("Precision:",precision_score(y_test,y_pred))
print("Recall:",recall_score(y_test,y_pred))
print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1-Score",f1_score(y_test,y_pred))
from sklearn import metrics
import matplotlib.pyplot as plt
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=0)
plt.plot(tpr,fpr)
plt.show()
# Out:
# Trained:  SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=1000, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)
# Precision: 1.0
# Recall: 0.0254609306409
# Accuracy: 0.514223194748
# F1-Score 0.0496575342466
