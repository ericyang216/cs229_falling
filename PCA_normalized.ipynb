# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
hd_data = pd.read_csv('2015_sort.csv')

# %%
hd_data = hd_data.dropna(0, thresh = 30)
hd_data = hd_data.dropna(axis=1)

# %%
df_norm = hd_data[[ 'smart_1_normalized', 'smart_3_normalized', 'smart_4_normalized', 'smart_5_normalized',
           'smart_7_normalized','smart_12_normalized', 'smart_194_normalized', 
           'smart_197_normalized', 'smart_198_normalized', 'smart_199_normalized'
           ]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = StandardScaler().fit_transform(df_norm)

# %%
from sklearn.decomposition import PCA
sklearn_pca = PCA(n_components=2)
reduced_data = sklearn_pca.fit_transform(x)
import matplotlib.pyplot as plt
fig = plt.figure()
plt = fig.add_subplot(111)
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c='b', label='HD points reduced')
#plt.scatter([:, 0], x[:, 1], c='r', label='HD points reduced')
plt.title("PCA")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-dff2e7e4ba6e> in <module>
#       7 plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c='b', label='HD points reduced')
#       8 #plt.scatter([:, 0], x[:, 1], c='r', label='HD points reduced')
# ----> 9 plt.title("PCA")
#      10 plt.legend()
#      11 plt.show()
#
# TypeError: 'Text' object is not callable

# %%
from matplotlib import *
from sklearn.decomposition import PCA
sklearn_pca = PCA(n_components=2) # number of components to keep
sklearn_transf = sklearn_pca.fit_transform(x)

plt.figure()

for label,marker,color in zip(
        #range(1,4),('x', 'o', '^'),('blue', 'red', 'green')):
        range(1,3),('o', 'o'),('blue','green')):

    plt.scatter(reduced_data[:, 0], reduced_data[:, 1],
                marker=marker,
                color=color,
                alpha=0.7,
                label='class {}'.format(label)
                )

plt.xlabel('vector 1')
plt.ylabel('vector 2')

plt.legend()
plt.title('Most significant singular vectors after linear transformation via PCA')

plt.show()

# %%
import pandas as pd
# load dataset into Pandas DataFrame
df = pd.read_csv('2015_sort.csv', names=['smart_1_normalized', 'smart_3_normalized', 'smart_4_normalized', 'smart_5_normalized',
           'smart_7_normalized','smart_12_normalized', 'smart_194_normalized', 
           'smart_197_normalized', 'smart_198_normalized', 'smart_199_normalized','failure'])

# %%
hd_data = pd.read_csv('2015_sort.csv')

# %%
hd_data = hd_data.dropna(0, thresh = 30)
hd_data = hd_data.dropna(axis=1)
hd_data
# Out:
#           date    serial_number                    model  capacity_bytes  \
# 0     04-12-15   MJ1311YNG6KXVA  Hitachi HDS5C3030ALA630    3.000000e+12
# 1     27-01-15         9XW03B5R             ST31500541AS    1.500000e+12
# 2     13-04-15   JK1160YAHP0HTT  Hitachi HDS722020ALA330    2.000000e+12
# 3     18-10-15   PL1331LAGR6BMH     HGST HMS5C4040ALE640    4.000000e+12
# 4     13-04-15  WD-WMC1T0751577             WDC WD30EFRX    3.000000e+12
# 5     13-11-15         Z30252DE              ST4000DM000    4.000000e+12
# 6     10-05-15   MK0331YHGT7NUA  Hitachi HDS723030ALA640    3.000000e+12
# 7     31-03-15         Z3029GHM              ST4000DM000    4.000000e+12
# 8     23-02-15   PL1331LAGR638H     HGST HMS5C4040ALE640    4.000000e+12
# 9     06-10-15         S300Z7HQ              ST4000DM000    4.000000e+12
# 10    06-09-15         Z3020MJJ              ST4000DM000    4.000000e+12
# 11    13-02-15   S2T0J9ACB00421            ST250LM004 HN    2.500000e+11
# ...

# %%
from sklearn.preprocessing import StandardScaler
features = ['failure','smart_1_normalized', 'smart_3_normalized', 'smart_4_normalized', 'smart_5_normalized',
           'smart_7_normalized','smart_12_normalized', 'smart_194_normalized', 
           'smart_197_normalized', 'smart_198_normalized', 'smart_199_normalized','failure']
# Separating out the features
x = hd_data.loc[:, features].values
#print(x)
#print(x)
# Separating out the target
y = hd_data.loc[:,['failure']].values
#print(y)
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, hd_data[['failure']]], axis = 1)

# %%
from matplotlib import *
import sys
import pylab as pl
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
#targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
failures = [0, 1]
colors = ['r', 'g']
for failure, color in zip(failures,colors):
    indicesToKeep = finalDf['failure'] == failure
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , alpha = 0.8
               , s = 40)
ax.legend(failures)
ax.grid()

# %%
import pandas as pd
import pylab as pl
from sklearn.decomposition import PCA

# load dataset
#iris = datasets.load_iris()
df = pd.read_csv('2015_sample.csv')

# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df_norm),columns = df_norm.columns) 

# PCA
pca = PCA(n_components=2)
pca.fit_transform(data_scaled)

# Dump components relations with features:
print(pd.DataFrame(pca.components_,columns=data_scaled.columns,index = ['PC-1','PC-2']))
# Out:
#       smart_1_normalized  smart_3_normalized  smart_4_normalized  \
# PC-1            0.381671            0.325534            0.007002
# PC-2            0.249785           -0.460486           -0.064099
#
#       smart_5_normalized  smart_7_normalized  smart_12_normalized  \
# PC-1            0.479014            0.405562                 -0.0
# PC-2            0.118600           -0.096951                 -0.0
#
#       smart_194_normalized  smart_197_normalized  smart_198_normalized  \
# PC-1              0.083797              0.491284              0.325559
# PC-2             -0.813226              0.112398              0.154970
#
#       smart_199_normalized
# PC-1                  -0.0
# PC-2                  -0.0

# %%
print ("Variance captured by each principal component = ")
print(pca.explained_variance_ratio_)

print ("\nTotal Variance captured by principal components = ")
total_var = np.cumsum(sklearn_pca.explained_variance_ratio_)[1]
print(total_var)
# Out:
# Variance captured by each principal component =
# [0.48710805 0.16915148]
#
# Total Variance captured by principal components =
# 0.6119350877246931
